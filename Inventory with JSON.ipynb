# %%
import json
import time

sale=""

fd = open('Records.json', 'r')
js = fd.read()
fd.close()

record = json.loads(js)  # Convert JSON string to dictionary


print("-------------MENU---------------\n")
for key in record.keys():
    print(key,":", record[key]["Name"],"|", record[key]["Price"],"|", record[key]["Qn"])
    
print("--------------------------------\n")   

ui_name = str(input("Enter your name    : "))
ui_mail = str(input("Enter Mail ID      : "))
ui_ph = str(input("Enter Phone No     :  "))
ui_pr= str(input("Enter Product ID :"))
ui_qn= int(input("Enter Quantity :"))

if (record[ui_pr]['Qn'] >= ui_qn):

    # Reduce the stock
    record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
    print("Name      : ", record[ui_pr]["Name"])
    print("Price (Rs): ", record[ui_pr]["Price"])
    print("Quantity  : ", ui_qn)
    print("---------------------------------------------")
    print("Billing   : ", ui_qn * record[ui_pr]["Price"], "Rs")
    print("---------------------------------------------")

    sale = '1'+","+ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+str(ui_qn * record[ui_pr]["Price"])+","+time.ctime()
    
else:
    
    print("Sorry, We're not having enough quanity of product in our Inventory.")
    print("We're only having " ,record[ui_pr]['Qn'] , " quantity.")
    print("---------------------------------------------")
    
    ch = str(input("Press Y/y to purchase: "))
    
    if(ch == "Y" or ch == 'y'):

        print("---------------------------------------------")
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"])
        print("Quantity  : ", record[ui_pr]['Qn'])
        print("---------------------------------------------")
        print("Billing   : ", record[ui_pr]['Qn'] * record[ui_pr]["Price"], "Rs")
        print("---------------------------------------------")

        record[ui_pr]['Qn'] = 0

        sale = '1'+","+ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+str(ui_qn * record[ui_pr]["Price"])+","+time.ctime()
        
    else:
        print("Thanks!")

js= json.dumps(record)

fd= open("Records.json","w")
fd.write(js)
fd.close()

fd = open('Sales.txt', 'a')
fd.write(sale)
fd.close()
# Out:
# -------------MENU---------------
#
# 1001 : 5-Star | 10 | 198
# 1002 : Donut | 20 | 50
# 1003 : Candy | 2 | 200
# 1004 : Chocolate-Cake | 500 | 0
# 1005 : Blueberry-Cake | 600 | 5
# --------------------------------
# Enter your name    :  bob
# Enter Mail ID      :  bob@gmail.com
# Enter Phone No     :   23189535595
# Enter Product ID : 1005
# Enter Quantity : 2
# Name      :  Blueberry-Cake
# Price (Rs):  600
# Quantity  :  2
# ---------------------------------------------
# Billing   :  1200 Rs
# ---------------------------------------------

# %%
record
# Out:
# {'1001': {'Name': '5-Star', 'Price': 10, 'Qn': 198},
#  '1002': {'Name': 'Donut', 'Price': 20, 'Qn': 50},
#  '1003': {'Name': 'Candy', 'Price': 2, 'Qn': 200},
#  '1004': {'Name': 'Chocolate-Cake', 'Price': 500, 'Qn': 10},
#  '1005': {'Name': 'Blueberry-Cake', 'Price': 600, 'Qn': 6}}
